# %%
from tqdm import tqdm, trange

from datasets import load_dataset
import pandas as pd
import functools
import sys
from pathlib import Path
from typing import Callable

# import circuitsvis as cv
import einops
import numpy as np
import torch as t
import torch.nn as nn
import torch.nn.functional as F
# from IPython.display import display
from jaxtyping import Float, Int
from torch import Tensor
from tqdm import tqdm
from transformer_lens import (
    ActivationCache,
    FactoredMatrix,
    HookedTransformer,
    HookedTransformerConfig,
    HookedEncoderDecoder,
    HookedEncoder,
    utils,
)
from transformer_lens.hook_points import HookPoint

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from datasets import load_dataset
from transformers import AutoTokenizer
from transformer_lens import HookedTransformer
import os
import json
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 20
#      18 from torch import Tensor
#      19 from tqdm import tqdm
# ---> 20 from transformer_lens import (
#      21     ActivationCache,
#      22     FactoredMatrix,
#      23     HookedTransformer,
#      24     HookedTransformerConfig,
#      25     HookedEncoderDecoder,
#      26     HookedEncoder,
#      27     utils,
#      28 )
#      29 from transformer_lens.hook_points import HookPoint
#      31 import torch
#
# File ~/.local/lib/python3.8/site-packages/transformer_lens/__init__.py:4
#       2 from . import utils
#       3 from . import evals
# ----> 4 from .past_key_value_caching import (
#       5     HookedTransformerKeyValueCache,
#       6     HookedTransformerKeyValueCacheEntry,
#       7 )
#       8 from . import components
#       9 from . import factories
#
# File ~/.local/lib/python3.8/site-packages/transformer_lens/past_key_value_caching.py:14
#      11 from jaxtyping import Float, Int
#      13 from transformer_lens.HookedTransformerConfig import HookedTransformerConfig
# ---> 14 from transformer_lens.utilities.devices import get_device_for_block_index
#      17 @dataclass
#      18 class HookedTransformerKeyValueCacheEntry:
#      19     past_keys: Float[torch.Tensor, "batch pos_so_far n_heads d_head"]
#
# File ~/.local/lib/python3.8/site-packages/transformer_lens/utilities/devices.py:16
#      12 from torch import nn
#      14 import transformer_lens
# ---> 16 AvailableDeviceMemory = list[tuple[int, int]]
#      17 """
#      18 This type is passed around between different CUDA memory operations.
#      19 The first entry of each tuple will be the device index.
#      20 The second entry will be how much memory is currently available.
#      21 """
#      24 def calculate_available_device_cuda_memory(i: int) -> int:
#
# TypeError: 'type' object is not subscriptable

# %%
from eindex import eindex

# %%
pip install git+https://github.com/callummcdougall/eindex.git
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting git+https://github.com/callummcdougall/eindex.git
#   Cloning https://github.com/callummcdougall/eindex.git to /tmp/pip-req-build-chli56u7
#   Running command git clone --filter=blob:none --quiet https://github.com/callummcdougall/eindex.git /tmp/pip-req-build-chli56u7
#   Resolved https://github.com/callummcdougall/eindex.git to commit 39da17a59dcce5caee35c9d00d4a22ba33efe722
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: einops in /home/kokil/.local/lib/python3.8/site-packages (from eindex-callum==0.1.1) (0.8.1)
# Requirement already satisfied: torch in /home/kokil/.local/lib/python3.8/site-packages (from eindex-callum==0.1.1) (2.4.0)
# Requirement already satisfied: filelock in /home/kokil/.local/lib/python3.8/site-packages (from torch->eindex-callum==0.1.1) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/kokil/.local/lib/python3.8/site-packages (from torch->eindex-callum==0.1.1) (4.12.2)
# Requirement already satisfied: sympy in /home/kokil/.local/lib/python3.8/site-packages (from torch->eindex-callum==0.1.1) (1.13.1)
# Requirement already satisfied: networkx in /home/kokil/.local/lib/python3.8/site-packages (from torch->eindex-callum==0.1.1) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from torch->eindex-callum==0.1.1) (3.1.3)
# Requirement already satisfied: fsspec in /home/kokil/.local/lib/python3.8/site-packages (from torch->eindex-callum==0.1.1) (2024.5.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/kokil/.local/lib/python3.8/site-packages (from torch->eindex-callum==0.1.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/kokil/.local/lib/python3.8/site-packages (from torch->eindex-callum==0.1.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/kokil/.local/lib/python3.8/site-packages (from torch->eindex-callum==0.1.1) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/kokil/.local/lib/python3.8/site-packages (from torch->eindex-callum==0.1.1) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/kokil/.local/lib/python3.8/site-packages (from torch->eindex-callum==0.1.1) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/kokil/.local/lib/python3.8/site-packages (from torch->eindex-callum==0.1.1) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/kokil/.local/lib/python3.8/site-packages (from torch->eindex-callum==0.1.1) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/kokil/.local/lib/python3.8/site-packages (from torch->eindex-callum==0.1.1) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/kokil/.local/lib/python3.8/site-packages (from torch->eindex-callum==0.1.1) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/kokil/.local/lib/python3.8/site-packages (from torch->eindex-callum==0.1.1) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/kokil/.local/lib/python3.8/site-packages (from torch->eindex-callum==0.1.1) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/kokil/.local/lib/python3.8/site-packages (from torch->eindex-callum==0.1.1) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/kokil/.local/lib/python3.8/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->eindex-callum==0.1.1) (12.6.20)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.8/dist-packages (from jinja2->torch->eindex-callum==0.1.1) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/kokil/.local/lib/python3.8/site-packages (from sympy->torch->eindex-callum==0.1.1) (1.3.0)
# Building wheels for collected packages: eindex-callum
#   Building wheel for eindex-callum (setup.py) ... done
#   Created wheel for eindex-callum: filename=eindex_callum-0.1.1-py3-none-any.whl size=8350 sha256=3554a53ff0786fee0d7c47b6e03be7202fa23dcb0ed81f17fa9a6f406e6889d0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-4njlwtru/wheels/e0/27/bc/b67a4b3798f321fa1b4530c5c3ebdfc93e6ad18da47e008e84
# Successfully built eindex-callum
# Installing collected packages: eindex-callum
# Successfully installed eindex-callum-0.1.1
# Note: you may need to restart the kernel to use updated packages.
