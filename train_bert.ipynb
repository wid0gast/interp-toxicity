# %%
import functools
import sys
from pathlib import Path
from typing import Callable

# %%
from platform import python_version

print(python_version())
# Out:
# 3.9.5

# %%
# !pip install transformer-lens
# Out:
# Requirement already satisfied: transformer-lens in /home/kokil/.local/lib/python3.8/site-packages (2.15.0)
# Requirement already satisfied: accelerate>=0.23.0 in /home/kokil/.local/lib/python3.8/site-packages (from transformer-lens) (0.34.2)
# Requirement already satisfied: beartype<0.15.0,>=0.14.1 in /home/kokil/.local/lib/python3.8/site-packages (from transformer-lens) (0.14.1)
# Requirement already satisfied: better-abc<0.0.4,>=0.0.3 in /home/kokil/.local/lib/python3.8/site-packages (from transformer-lens) (0.0.3)
# Requirement already satisfied: pandas>=1.1.5 in /home/kokil/.local/lib/python3.8/site-packages (from transformer-lens) (2.0.3)
# Requirement already satisfied: sentencepiece in /home/kokil/.local/lib/python3.8/site-packages (from transformer-lens) (0.2.0)
# Requirement already satisfied: typeguard<5.0,>=4.2 in /home/kokil/.local/lib/python3.8/site-packages (from transformer-lens) (4.4.0)
# Requirement already satisfied: transformers-stream-generator<0.0.6,>=0.0.5 in /home/kokil/.local/lib/python3.8/site-packages (from transformer-lens) (0.0.5)
# Requirement already satisfied: datasets>=2.7.1 in /home/kokil/.local/lib/python3.8/site-packages (from transformer-lens) (2.20.0)
# Requirement already satisfied: numpy<1.25,>=1.20; python_version == "3.8" in /home/kokil/.local/lib/python3.8/site-packages (from transformer-lens) (1.24.4)
# Requirement already satisfied: transformers>=4.43 in /home/kokil/.local/lib/python3.8/site-packages (from transformer-lens) (4.45.2)
# Requirement already satisfied: typing-extensions in /home/kokil/.local/lib/python3.8/site-packages (from transformer-lens) (4.12.2)
# Requirement already satisfied: einops>=0.6.0 in /home/kokil/.local/lib/python3.8/site-packages (from transformer-lens) (0.8.1)
# Requirement already satisfied: fancy-einsum>=0.0.3 in /home/kokil/.local/lib/python3.8/site-packages (from transformer-lens) (0.0.3)
# Requirement already satisfied: jaxtyping>=0.2.11 in /home/kokil/.local/lib/python3.8/site-packages (from transformer-lens) (0.2.19)
# Requirement already satisfied: torch>=2.2 in /home/kokil/.local/lib/python3.8/site-packages (from transformer-lens) (2.4.0)
# Requirement already satisfied: wandb>=0.13.5 in /home/kokil/.local/lib/python3.8/site-packages (from transformer-lens) (0.18.0)
# Requirement already satisfied: rich>=12.6.0 in /home/kokil/.local/lib/python3.8/site-packages (from transformer-lens) (13.8.1)
# Requirement already satisfied: tqdm>=4.64.1 in /home/kokil/.local/lib/python3.8/site-packages (from transformer-lens) (4.66.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (from accelerate>=0.23.0->transformer-lens) (6.0.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.8/dist-packages (from accelerate>=0.23.0->transformer-lens) (5.9.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from accelerate>=0.23.0->transformer-lens) (23.2)
# Requirement already satisfied: safetensors>=0.4.3 in /home/kokil/.local/lib/python3.8/site-packages (from accelerate>=0.23.0->transformer-lens) (0.4.3)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /home/kokil/.local/lib/python3.8/site-packages (from accelerate>=0.23.0->transformer-lens) (0.24.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.1.5->transformer-lens) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/kokil/.local/lib/python3.8/site-packages (from pandas>=1.1.5->transformer-lens) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.1.5->transformer-lens) (2023.3.post1)
# Requirement already satisfied: importlib-metadata>=3.6; python_version < "3.10" in /usr/local/lib/python3.8/dist-packages (from typeguard<5.0,>=4.2->transformer-lens) (7.0.1)
# Requirement already satisfied: pyarrow-hotfix in /home/kokil/.local/lib/python3.8/site-packages (from datasets>=2.7.1->transformer-lens) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/kokil/.local/lib/python3.8/site-packages (from datasets>=2.7.1->transformer-lens) (0.3.8)
# Requirement already satisfied: fsspec[http]<=2024.5.0,>=2023.1.0 in /home/kokil/.local/lib/python3.8/site-packages (from datasets>=2.7.1->transformer-lens) (2024.5.0)
# Requirement already satisfied: requests>=2.32.2 in /home/kokil/.local/lib/python3.8/site-packages (from datasets>=2.7.1->transformer-lens) (2.32.3)
# Requirement already satisfied: filelock in /home/kokil/.local/lib/python3.8/site-packages (from datasets>=2.7.1->transformer-lens) (3.15.4)
# Requirement already satisfied: multiprocess in /home/kokil/.local/lib/python3.8/site-packages (from datasets>=2.7.1->transformer-lens) (0.70.16)
# Requirement already satisfied: aiohttp in /home/kokil/.local/lib/python3.8/site-packages (from datasets>=2.7.1->transformer-lens) (3.10.2)
# Requirement already satisfied: xxhash in /home/kokil/.local/lib/python3.8/site-packages (from datasets>=2.7.1->transformer-lens) (3.4.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/kokil/.local/lib/python3.8/site-packages (from datasets>=2.7.1->transformer-lens) (17.0.0)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /home/kokil/.local/lib/python3.8/site-packages (from transformers>=4.43->transformer-lens) (0.20.3)
# Requirement already satisfied: regex!=2019.12.17 in /home/kokil/.local/lib/python3.8/site-packages (from transformers>=4.43->transformer-lens) (2024.7.24)
# Requirement already satisfied: triton==3.0.0; platform_system == "Linux" and platform_machine == "x86_64" and python_version < "3.13" in /home/kokil/.local/lib/python3.8/site-packages (from torch>=2.2->transformer-lens) (3.0.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from torch>=2.2->transformer-lens) (3.1.3)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1; platform_system == "Linux" and platform_machine == "x86_64" in /home/kokil/.local/lib/python3.8/site-packages (from torch>=2.2->transformer-lens) (12.1.3.1)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106; platform_system == "Linux" and platform_machine == "x86_64" in /home/kokil/.local/lib/python3.8/site-packages (from torch>=2.2->transformer-lens) (10.3.2.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5; platform_system == "Linux" and platform_machine == "x86_64" in /home/kokil/.local/lib/python3.8/site-packages (from torch>=2.2->transformer-lens) (2.20.5)
# Requirement already satisfied: sympy in /home/kokil/.local/lib/python3.8/site-packages (from torch>=2.2->transformer-lens) (1.13.1)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106; platform_system == "Linux" and platform_machine == "x86_64" in /home/kokil/.local/lib/python3.8/site-packages (from torch>=2.2->transformer-lens) (12.1.0.106)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54; platform_system == "Linux" and platform_machine == "x86_64" in /home/kokil/.local/lib/python3.8/site-packages (from torch>=2.2->transformer-lens) (11.0.2.54)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64" in /home/kokil/.local/lib/python3.8/site-packages (from torch>=2.2->transformer-lens) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64" in /home/kokil/.local/lib/python3.8/site-packages (from torch>=2.2->transformer-lens) (9.1.0.70)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107; platform_system == "Linux" and platform_machine == "x86_64" in /home/kokil/.local/lib/python3.8/site-packages (from torch>=2.2->transformer-lens) (11.4.5.107)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64" in /home/kokil/.local/lib/python3.8/site-packages (from torch>=2.2->transformer-lens) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64" in /home/kokil/.local/lib/python3.8/site-packages (from torch>=2.2->transformer-lens) (12.1.105)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64" in /home/kokil/.local/lib/python3.8/site-packages (from torch>=2.2->transformer-lens) (12.1.105)
# Requirement already satisfied: networkx in /home/kokil/.local/lib/python3.8/site-packages (from torch>=2.2->transformer-lens) (3.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /home/kokil/.local/lib/python3.8/site-packages (from wandb>=0.13.5->transformer-lens) (3.1.43)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from wandb>=0.13.5->transformer-lens) (45.2.0)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /home/kokil/.local/lib/python3.8/site-packages (from wandb>=0.13.5->transformer-lens) (2.14.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /home/kokil/.local/lib/python3.8/site-packages (from wandb>=0.13.5->transformer-lens) (0.4.0)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /home/kokil/.local/lib/python3.8/site-packages (from wandb>=0.13.5->transformer-lens) (8.1.7)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.12.0; python_version < "3.9" and sys_platform == "linux" in /home/kokil/.local/lib/python3.8/site-packages (from wandb>=0.13.5->transformer-lens) (5.28.1)
# Requirement already satisfied: setproctitle in /home/kokil/.local/lib/python3.8/site-packages (from wandb>=0.13.5->transformer-lens) (1.3.3)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.8/dist-packages (from wandb>=0.13.5->transformer-lens) (4.1.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from rich>=12.6.0->transformer-lens) (2.17.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/kokil/.local/lib/python3.8/site-packages (from rich>=12.6.0->transformer-lens) (3.0.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->transformer-lens) (1.14.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=3.6; python_version < "3.10"->typeguard<5.0,>=4.2->transformer-lens) (3.17.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests>=2.32.2->datasets>=2.7.1->transformer-lens) (2019.11.28)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.32.2->datasets>=2.7.1->transformer-lens) (2.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/kokil/.local/lib/python3.8/site-packages (from requests>=2.32.2->datasets>=2.7.1->transformer-lens) (1.26.20)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.32.2->datasets>=2.7.1->transformer-lens) (3.3.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/kokil/.local/lib/python3.8/site-packages (from aiohttp->datasets>=2.7.1->transformer-lens) (2.3.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/kokil/.local/lib/python3.8/site-packages (from aiohttp->datasets>=2.7.1->transformer-lens) (1.9.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/kokil/.local/lib/python3.8/site-packages (from aiohttp->datasets>=2.7.1->transformer-lens) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0; python_version < "3.11" in /home/kokil/.local/lib/python3.8/site-packages (from aiohttp->datasets>=2.7.1->transformer-lens) (4.0.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/kokil/.local/lib/python3.8/site-packages (from aiohttp->datasets>=2.7.1->transformer-lens) (6.0.5)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets>=2.7.1->transformer-lens) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/kokil/.local/lib/python3.8/site-packages (from aiohttp->datasets>=2.7.1->transformer-lens) (1.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.8/dist-packages (from jinja2->torch>=2.2->transformer-lens) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/kokil/.local/lib/python3.8/site-packages (from sympy->torch>=2.2->transformer-lens) (1.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/kokil/.local/lib/python3.8/site-packages (from nvidia-cusparse-cu12==12.1.0.106; platform_system == "Linux" and platform_machine == "x86_64"->torch>=2.2->transformer-lens) (12.6.20)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/kokil/.local/lib/python3.8/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb>=0.13.5->transformer-lens) (4.0.11)
# Requirement already satisfied: mdurl~=0.1 in /home/kokil/.local/lib/python3.8/site-packages (from markdown-it-py>=2.2.0->rich>=12.6.0->transformer-lens) (0.1.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/kokil/.local/lib/python3.8/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.13.5->transformer-lens) (5.0.1)

# %%
import transformer_lens
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import transformer_lens
#
# ModuleNotFoundError: No module named 'transformer_lens'

# %%
import einops
import numpy as np
import torch as t
import torch.nn as nn
import torch.nn.functional as F
from torch import Tensor
from tqdm import tqdm
from transformer_lens import (
    ActivationCache,
    FactoredMatrix,
    HookedTransformer,
    HookedTransformerConfig,
    utils,
)
from transformer_lens.hook_points import HookPoint
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import einops
#       2 import numpy as np
#       3 import torch as t
#
# ModuleNotFoundError: No module named 'einops'

# %%
device = t.device("mps" if t.backends.mps.is_available() else "cuda" if t.cuda.is_available() else "cpu")

# %%
pip install transformer-lens
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformer-lens in /home/kokil/.local/lib/python3.8/site-packages (2.15.0)
# Requirement already satisfied: accelerate>=0.23.0 in /home/kokil/.local/lib/python3.8/site-packages (from transformer-lens) (0.34.2)
# Requirement already satisfied: beartype<0.15.0,>=0.14.1 in /home/kokil/.local/lib/python3.8/site-packages (from transformer-lens) (0.14.1)
# Requirement already satisfied: better-abc<0.0.4,>=0.0.3 in /home/kokil/.local/lib/python3.8/site-packages (from transformer-lens) (0.0.3)
# Requirement already satisfied: datasets>=2.7.1 in /home/kokil/.local/lib/python3.8/site-packages (from transformer-lens) (2.20.0)
# Requirement already satisfied: einops>=0.6.0 in /home/kokil/.local/lib/python3.8/site-packages (from transformer-lens) (0.8.1)
# Requirement already satisfied: fancy-einsum>=0.0.3 in /home/kokil/.local/lib/python3.8/site-packages (from transformer-lens) (0.0.3)
# Requirement already satisfied: jaxtyping>=0.2.11 in /home/kokil/.local/lib/python3.8/site-packages (from transformer-lens) (0.2.19)
# Requirement already satisfied: numpy<1.25,>=1.20 in /home/kokil/.local/lib/python3.8/site-packages (from transformer-lens) (1.24.4)
# Requirement already satisfied: pandas>=1.1.5 in /home/kokil/.local/lib/python3.8/site-packages (from transformer-lens) (2.0.3)
# Requirement already satisfied: rich>=12.6.0 in /home/kokil/.local/lib/python3.8/site-packages (from transformer-lens) (13.8.1)
# Requirement already satisfied: sentencepiece in /home/kokil/.local/lib/python3.8/site-packages (from transformer-lens) (0.2.0)
# Requirement already satisfied: torch>=2.2 in /home/kokil/.local/lib/python3.8/site-packages (from transformer-lens) (2.4.0)
# Requirement already satisfied: tqdm>=4.64.1 in /home/kokil/.local/lib/python3.8/site-packages (from transformer-lens) (4.66.4)
# Requirement already satisfied: transformers>=4.43 in /home/kokil/.local/lib/python3.8/site-packages (from transformer-lens) (4.45.2)
# Requirement already satisfied: transformers-stream-generator<0.0.6,>=0.0.5 in /home/kokil/.local/lib/python3.8/site-packages (from transformer-lens) (0.0.5)
# Requirement already satisfied: typeguard<5.0,>=4.2 in /home/kokil/.local/lib/python3.8/site-packages (from transformer-lens) (4.4.0)
# Requirement already satisfied: typing-extensions in /home/kokil/.local/lib/python3.8/site-packages (from transformer-lens) (4.12.2)
# Requirement already satisfied: wandb>=0.13.5 in /home/kokil/.local/lib/python3.8/site-packages (from transformer-lens) (0.18.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from accelerate>=0.23.0->transformer-lens) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.8/dist-packages (from accelerate>=0.23.0->transformer-lens) (5.9.7)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (from accelerate>=0.23.0->transformer-lens) (6.0.1)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /home/kokil/.local/lib/python3.8/site-packages (from accelerate>=0.23.0->transformer-lens) (0.24.7)
# Requirement already satisfied: safetensors>=0.4.3 in /home/kokil/.local/lib/python3.8/site-packages (from accelerate>=0.23.0->transformer-lens) (0.4.3)
# Requirement already satisfied: filelock in /home/kokil/.local/lib/python3.8/site-packages (from datasets>=2.7.1->transformer-lens) (3.15.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/kokil/.local/lib/python3.8/site-packages (from datasets>=2.7.1->transformer-lens) (17.0.0)
# Requirement already satisfied: pyarrow-hotfix in /home/kokil/.local/lib/python3.8/site-packages (from datasets>=2.7.1->transformer-lens) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/kokil/.local/lib/python3.8/site-packages (from datasets>=2.7.1->transformer-lens) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in /home/kokil/.local/lib/python3.8/site-packages (from datasets>=2.7.1->transformer-lens) (2.32.3)
# Requirement already satisfied: xxhash in /home/kokil/.local/lib/python3.8/site-packages (from datasets>=2.7.1->transformer-lens) (3.4.1)
# Requirement already satisfied: multiprocess in /home/kokil/.local/lib/python3.8/site-packages (from datasets>=2.7.1->transformer-lens) (0.70.16)
# Requirement already satisfied: fsspec<=2024.5.0,>=2023.1.0 in /home/kokil/.local/lib/python3.8/site-packages (from fsspec[http]<=2024.5.0,>=2023.1.0->datasets>=2.7.1->transformer-lens) (2024.5.0)
# Requirement already satisfied: aiohttp in /home/kokil/.local/lib/python3.8/site-packages (from datasets>=2.7.1->transformer-lens) (3.10.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.1.5->transformer-lens) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.1.5->transformer-lens) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/kokil/.local/lib/python3.8/site-packages (from pandas>=1.1.5->transformer-lens) (2024.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/kokil/.local/lib/python3.8/site-packages (from rich>=12.6.0->transformer-lens) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from rich>=12.6.0->transformer-lens) (2.17.2)
# Requirement already satisfied: sympy in /home/kokil/.local/lib/python3.8/site-packages (from torch>=2.2->transformer-lens) (1.13.1)
# Requirement already satisfied: networkx in /home/kokil/.local/lib/python3.8/site-packages (from torch>=2.2->transformer-lens) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from torch>=2.2->transformer-lens) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/kokil/.local/lib/python3.8/site-packages (from torch>=2.2->transformer-lens) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/kokil/.local/lib/python3.8/site-packages (from torch>=2.2->transformer-lens) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/kokil/.local/lib/python3.8/site-packages (from torch>=2.2->transformer-lens) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/kokil/.local/lib/python3.8/site-packages (from torch>=2.2->transformer-lens) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/kokil/.local/lib/python3.8/site-packages (from torch>=2.2->transformer-lens) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/kokil/.local/lib/python3.8/site-packages (from torch>=2.2->transformer-lens) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/kokil/.local/lib/python3.8/site-packages (from torch>=2.2->transformer-lens) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/kokil/.local/lib/python3.8/site-packages (from torch>=2.2->transformer-lens) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/kokil/.local/lib/python3.8/site-packages (from torch>=2.2->transformer-lens) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/kokil/.local/lib/python3.8/site-packages (from torch>=2.2->transformer-lens) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/kokil/.local/lib/python3.8/site-packages (from torch>=2.2->transformer-lens) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/kokil/.local/lib/python3.8/site-packages (from torch>=2.2->transformer-lens) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/kokil/.local/lib/python3.8/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.2->transformer-lens) (12.6.20)
# Requirement already satisfied: regex!=2019.12.17 in /home/kokil/.local/lib/python3.8/site-packages (from transformers>=4.43->transformer-lens) (2024.7.24)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /home/kokil/.local/lib/python3.8/site-packages (from transformers>=4.43->transformer-lens) (0.20.3)
# Requirement already satisfied: importlib-metadata>=3.6 in /usr/local/lib/python3.8/dist-packages (from typeguard<5.0,>=4.2->transformer-lens) (7.0.1)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /home/kokil/.local/lib/python3.8/site-packages (from wandb>=0.13.5->transformer-lens) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /home/kokil/.local/lib/python3.8/site-packages (from wandb>=0.13.5->transformer-lens) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /home/kokil/.local/lib/python3.8/site-packages (from wandb>=0.13.5->transformer-lens) (3.1.43)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.8/dist-packages (from wandb>=0.13.5->transformer-lens) (4.1.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.12.0 in /home/kokil/.local/lib/python3.8/site-packages (from wandb>=0.13.5->transformer-lens) (5.28.1)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /home/kokil/.local/lib/python3.8/site-packages (from wandb>=0.13.5->transformer-lens) (2.14.0)
# Requirement already satisfied: setproctitle in /home/kokil/.local/lib/python3.8/site-packages (from wandb>=0.13.5->transformer-lens) (1.3.3)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from wandb>=0.13.5->transformer-lens) (45.2.0)
# Requirement already satisfied: six>=1.4.0 in /usr/lib/python3/dist-packages (from docker-pycreds>=0.4.0->wandb>=0.13.5->transformer-lens) (1.14.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/kokil/.local/lib/python3.8/site-packages (from aiohttp->datasets>=2.7.1->transformer-lens) (2.3.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/kokil/.local/lib/python3.8/site-packages (from aiohttp->datasets>=2.7.1->transformer-lens) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets>=2.7.1->transformer-lens) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/kokil/.local/lib/python3.8/site-packages (from aiohttp->datasets>=2.7.1->transformer-lens) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/kokil/.local/lib/python3.8/site-packages (from aiohttp->datasets>=2.7.1->transformer-lens) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/kokil/.local/lib/python3.8/site-packages (from aiohttp->datasets>=2.7.1->transformer-lens) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/kokil/.local/lib/python3.8/site-packages (from aiohttp->datasets>=2.7.1->transformer-lens) (4.0.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/kokil/.local/lib/python3.8/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb>=0.13.5->transformer-lens) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=3.6->typeguard<5.0,>=4.2->transformer-lens) (3.17.0)
# Requirement already satisfied: mdurl~=0.1 in /home/kokil/.local/lib/python3.8/site-packages (from markdown-it-py>=2.2.0->rich>=12.6.0->transformer-lens) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.32.2->datasets>=2.7.1->transformer-lens) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.32.2->datasets>=2.7.1->transformer-lens) (2.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/kokil/.local/lib/python3.8/site-packages (from requests>=2.32.2->datasets>=2.7.1->transformer-lens) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests>=2.32.2->datasets>=2.7.1->transformer-lens) (2019.11.28)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.8/dist-packages (from jinja2->torch>=2.2->transformer-lens) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/kokil/.local/lib/python3.8/site-packages (from sympy->torch>=2.2->transformer-lens) (1.3.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/kokil/.local/lib/python3.8/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.13.5->transformer-lens) (5.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import transformer_lens
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 import transformer_lens
#
# File ~/.local/lib/python3.8/site-packages/transformer_lens/__init__.py:4
#       2 from . import utils
#       3 from . import evals
# ----> 4 from .past_key_value_caching import (
#       5     HookedTransformerKeyValueCache,
#       6     HookedTransformerKeyValueCacheEntry,
#       7 )
#       8 from . import components
#       9 from . import factories
#
# File ~/.local/lib/python3.8/site-packages/transformer_lens/past_key_value_caching.py:14
#      11 from jaxtyping import Float, Int
#      13 from transformer_lens.HookedTransformerConfig import HookedTransformerConfig
# ---> 14 from transformer_lens.utilities.devices import get_device_for_block_index
#      17 @dataclass
#      18 class HookedTransformerKeyValueCacheEntry:
#      19     past_keys: Float[torch.Tensor, "batch pos_so_far n_heads d_head"]
#
# File ~/.local/lib/python3.8/site-packages/transformer_lens/utilities/devices.py:16
#      12 from torch import nn
#      14 import transformer_lens
# ---> 16 AvailableDeviceMemory = list[tuple[int, int]]
#      17 """
#      18 This type is passed around between different CUDA memory operations.
#      19 The first entry of each tuple will be the device index.
#      20 The second entry will be how much memory is currently available.
#      21 """
#      24 def calculate_available_device_cuda_memory(i: int) -> int:
#
# TypeError: 'type' object is not subscriptable
